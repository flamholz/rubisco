# %%
# %matplotlib inline

import numpy as np
import power_laws
import matplotlib.colors
import seaborn
import pandas as pd
import rubisco_data

from scipy import stats
from matplotlib import pyplot as plt

# %%
# Load the data from Excel, remove data points that are not comparable.
# raw_kin_df is everything in the file, kin_df is the subset with all relevant kinetic data.
fname = '../data/072618_rubisco_kinetics_merged.csv'
raw_kin_df, kin_df = rubisco_data.load_rubisco_data(fname)

# Want to split data in various ways
# Savir vs. Non-Savir (mostly new) data
savir_pmid = '20142476'
savir_df = raw_kin_df[raw_kin_df.pmid_or_doi == savir_pmid]
nonsavir_df = raw_kin_df[raw_kin_df.pmid_or_doi != savir_pmid]

# Group by RuBisCO form
grouped_form = raw_kin_df.groupby('isoform')

# Markers we use for plotting below.
markers = 'o><^dsphH*'

cnames = ["windows blue", "amber", "greyish brown", "dusty purple", "dusty teal", "dusty red", ]
named_colors = seaborn.xkcd_palette(cnames)

# %%
print(raw_kin_df.shape[0], 'total WT RuBisCOs')
print(raw_kin_df.species.unique().size, 'total unique species')
print(kin_df.shape[0], 'RuBisCOs with all core kinetic data measured')
# Out:
# 357 total WT RuBisCOs
# 286 total unique species
# 198 RuBisCOs with all core kinetic data measured

# %%
cols = ['S', 'vC', 'KC', 'KO', 'kon_C', 'kon_O']
all_F1 = raw_kin_df[raw_kin_df.isoform == '1']
r_cis = {}

for c in cols:
    print('vO vs %s' % c)
    vOs = raw_kin_df.vO
    vals = raw_kin_df[c]
    log_vOs = np.log(vOs)
    log_vals = np.log(vals)

    slope, intercept, r, p, stderr = power_laws.log_linregress(log_vOs, log_vals)
    print('Log-scale linear regression R = %.2f, P = %.2g' % (r, p))
    print('Spearman rank correlation R = %.2f, P = %.2g' % power_laws.log_spearmanr(log_vOs, log_vals))

    exps, pres, rs = power_laws.bootstrap_power_law_odr(vOs, vals)
    conf_range = [2.5, 97.5]
    pre_interval = np.percentile(pres, conf_range)
    exp_interval = np.percentile(exps, conf_range)
    rs_interval = np.percentile(rs, conf_range)
    
    r_cis[c] = rs_interval
    print(exp_interval)
    print(pre_interval)
    print(rs_interval)
    print()
# Out:
# vO vs S
# Log-scale linear regression R = 0.39, P = 1.2e-08
# Spearman rank correlation R = -0.23, P = 0.001
# [-0.33589089  1.6076983 ]
# [81.33214152 95.71749589]
# [0.03553719 0.68401112]
#
# vO vs vC
# Log-scale linear regression R = 0.46, P = 1.1e-11
# Spearman rank correlation R = 0.36, P = 2.7e-07
# [0.29923898 1.10715803]
# [3.15930191 3.55223887]
# [0.28074394 0.60351616]
#
# vO vs KC
# Log-scale linear regression R = -0.34, P = 1.3e-06
# Spearman rank correlation R = -0.27, P = 0.00014
# [-6.48955566 -0.91500414]
# [15.37777418 22.58644386]
# [0.14835664 0.49216276]
#
# vO vs KO
# Log-scale linear regression R = 0.54, P = 1.7e-16
# Spearman rank correlation R = 0.30, P = 2.1e-05
# [0.28723558 1.51586044]
# [451.13526129 535.15773827]
# [0.13878094 0.75708964]
#
# vO vs kon_C
# Log-scale linear regression R = 0.62, P = 1.9e-22
# Spearman rank correlation R = 0.52, P = 3.3e-15
# [0.9986341  2.36194221]
# [0.16606709 0.19903254]
# [0.45934559 0.74581952]
#
# vO vs kon_O
# Log-scale linear regression R = 0.38, P = 2.9e-08
# Spearman rank correlation R = 0.55, P = 2.8e-17
# [0.02622762 1.43450432]
# [0.00193423 0.00224709]
# [0.03093908 0.74209827]

# %%
# Description of the data set
figure = plt.figure(figsize=(15,7))

cols = ['S', 'vC', 'KC', 'KO', 'kon_C', 'kon_O']
titles = {'S': '$S$',
          'vC': '$v_C$',
          'KC': '$K_C$',
          'vO': '$v_O$',
          'KO': '$K_O$',
          'kon_C': '$k_{on,C}$',
          'kon_O': '$k_{on,O}$',
          'KRuBP': '$K_{RuBP}$'}
units = {'S': 'unitless',
         'vC': '$s^{-1}$',
         'KC': '$\mu M$',
         'vO': '$s^{-1}$',
         'KO': '$\mu M$',
         'kon_C': '$\mu M^{-1} s^{-1}$',
         'kon_O': '$\mu M^{-1} s^{-1}$',
         'KRuBP': '$\mu M$'}
lim = {'S': (1, 300),
       'vC': (7e-1, 20),
       'vO':(1e-2, 20),
       'KC': (1, 1e3),
       'KO': (50, 5e3),
       'kon_C': (7e-3, 1e0),
       'kon_O': (1e-4, 1e-2),
       'KRuBP': (0.1, 1.5e2)}
groups = {'1': 'I', 
          '2': 'II',
          '2_3': 'II/III', 
          '3': 'III'}

nsub = len(cols)
pal = seaborn.color_palette('Set3')

for i, c in enumerate(cols):
    mask = raw_kin_df[c].notnull()
    vals = raw_kin_df[mask][c]
    
    ax = plt.subplot(2, nsub/2.0, i+1)
    plt.xscale('log')
    plt.yscale('log')

    for j, (group, gdf) in enumerate(raw_kin_df.groupby('isoform')):
        if group not in ['1', '2']:
            continue
        
        color = named_colors[j]
        label = 'Form %s' % groups[group]
        
        mask = gdf[c].notnull() & gdf.vO.notnull()
        plt.scatter(gdf[mask].vO, gdf[mask][c], color=color, label=label)
        
        if group == '1':
            corr = '%.2f < R < %.2f' % (r_cis[c][0], r_cis[c][1])
            plt.text(0.95, 0.1, corr, transform=ax.transAxes,
                     fontsize=14, ha='right', va='top')
    
        if c == 'S':
            plt.legend(loc=3, frameon=True, fontsize=16)
    
    sigma_star = np.nanstd(np.log(raw_kin_df[c]))
    nvals = raw_kin_df[c].notnull().sum()
    ylabel = '%s (%s)' % (titles[c], units[c]) 

    plt.ylim(*lim[c])
    plt.xlim(0.05, 10)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.ylabel(ylabel, fontsize=24)
    plt.xlabel('$v_O$ ($s^{-1}$)', fontsize=24, ha='center')
    
    
plt.subplots_adjust(wspace=0.1)
plt.tight_layout()

plt.savefig('figS5/figS5_vO_corr.svg')
plt.savefig('figS5/figS5_vO_corr.png', dpi=400)

plt.show()
