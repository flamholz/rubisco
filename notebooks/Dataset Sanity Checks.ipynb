# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import rubisco_data
import seaborn as sns

from matplotlib import pyplot as plt

# %%
measurement2err_cols = {
    'KC': ['KC_SD'],
    'vC': ['vC_SD'],
    'S': ['S_SD'],
    'KO': ['KO_SD'],
    'KRuBP': ['KRuBP_SD'],
    'vO_reported': ['vO_SD_reported'],
    'vO': ['vO_95CI_low', 'vO_95CI_high'],
    'kon_C': ['kon_C_95CI_low', 'kon_C_95CI_high'],
    'kon_O': ['kon_O_95CI_low', 'kon_O_95CI_high'],
}

# error is not very often reported for kcatO. 
# assert at least 30 values for everything else
min_measurements = {"vO_SD_reported": 2}

# Helper functions for sanity checking dataframes
def check_col(df, colname, min_vals):
    mask = df[colname].notnull()
    assert(mask.sum() >= min_vals)
    assert(np.isfinite(df[mask][colname]).all())
    
def check_df(my_df):
    for col, err_cols in measurement2err_cols.items():
        for c in [col] + err_cols:
            min_vals = min_measurements.get(c, 30)
            check_col(my_df, c, min_vals)
            print(c, "passed column tests")

        if col.endswith('_reported'):
            # next check ensures error is inferred.
            # this does not happen on the vO_reported columns.
            continue

        for ec in err_cols:
            # should always have an error value when we have a primary value
            # since the data normalization infers error when absent
            mask = my_df[col].notnull()
            assert(my_df[mask][ec].notnull().all())
            print(ec, 'has values when', col, 'does')

# %%
# Merged dataset is the one we work with in most of the figures. 
merged_df = pd.read_csv('../data/DatasetS2_RubiscoKinetics_Merged.csv')

check_df(merged_df)
# Out:
# KC passed column tests
# KC_SD passed column tests
# KC_SD has values when KC does
# vC passed column tests
# vC_SD passed column tests
# vC_SD has values when vC does
# S passed column tests
# S_SD passed column tests
# S_SD has values when S does
# KO passed column tests
# KO_SD passed column tests
# KO_SD has values when KO does
# KRuBP passed column tests
# KRuBP_SD passed column tests
# KRuBP_SD has values when KRuBP does
# vO_reported passed column tests
# vO_SD_reported passed column tests
# vO passed column tests
# vO_95CI_low passed column tests
# vO_95CI_high passed column tests
# vO_95CI_low has values when vO does
# vO_95CI_high has values when vO does
# kon_C passed column tests
# kon_C_95CI_low passed column tests
# kon_C_95CI_high passed column tests
# kon_C_95CI_low has values when kon_C does
# kon_C_95CI_high has values when kon_C does
# kon_O passed column tests
# kon_O_95CI_low passed column tests
# kon_O_95CI_high passed column tests
# kon_O_95CI_low has values when kon_O does
# kon_O_95CI_high has values when kon_O does

# %%
# Merged dataset is the one we work with in most of the figures. 
full_df = pd.read_csv('../data/DatasetS4_RubiscoKineticsFull_Merged.csv')

check_df(full_df)
# Out:
# KC passed column tests
# KC_SD passed column tests
# KC_SD has values when KC does
# vC passed column tests
# vC_SD passed column tests
# vC_SD has values when vC does
# S passed column tests
# S_SD passed column tests
# S_SD has values when S does
# KO passed column tests
# KO_SD passed column tests
# KO_SD has values when KO does
# KRuBP passed column tests
# KRuBP_SD passed column tests
# KRuBP_SD has values when KRuBP does
# vO_reported passed column tests
# vO_SD_reported passed column tests
# vO passed column tests
# vO_95CI_low passed column tests
# vO_95CI_high passed column tests
# vO_95CI_low has values when vO does
# vO_95CI_high has values when vO does
# kon_C passed column tests
# kon_C_95CI_low passed column tests
# kon_C_95CI_high passed column tests
# kon_C_95CI_low has values when kon_C does
# kon_C_95CI_high has values when kon_C does
# kon_O passed column tests
# kon_O_95CI_low passed column tests
# kon_O_95CI_high passed column tests
# kon_O_95CI_low has values when kon_O does
# kon_O_95CI_high has values when kon_O does

# %%
def get_kin_dups(my_df):
    # check for duplicate rows after rounding to 1 sig fig.
    # all the duplicates should be with "Savir 2010" since we use this as a point of comparison
    measured_vars = 'KC, vC, S, KO'.split(', ')
    meta_plus_meas = ["species", "identifier", "short_ref", "primary"] + measured_vars
    rounded_df = my_df[meta_plus_meas].round(1)
    idxs = rounded_df.duplicated(measured_vars, keep=False)
    return rounded_df[idxs].sort_values(measured_vars)

# %%
# Merged dataset is the one we work with in most of the figures. 
merged_df = pd.read_csv('../data/DatasetS2_RubiscoKinetics_Merged.csv')

# Printing duplicates by 4 primary kinetic measurements - KC, kcatC, S and KO.
# Have manually verified that all the duplicates below are fine - i.e. the values are
# truly the same in the primary reference.
get_kin_dups(merged_df)
# Notice also that the listing includes some data from Savir. This is removed in a later
# filtering step to avoid data duplication when doing regression (see below).
# Out:
#                              species  \
# 220             Galdieria sulfuraria
# 275             Galdieria sulfuraria
# 94                       Glycine max
# 224                      Glycine max
# 218              Griffithsia monilis
# 274              Griffithsia monilis
# 213                Nicotiana tabacum
# 272                Nicotiana tabacum
# 139                 Chenopodium alba
# 217                 Chenopodium alba
# 138                Flaveria pringlei
# 216                Flaveria pringlei
# 135                Spinacia oleracea
# 215                Spinacia oleracea
# 95               Tetragonium expansa
# 228              Tetragonium expansa
# 96                    Lolium perenne
# 225                   Lolium perenne
# 126                Amaranthus edulis
# 210                Amaranthus edulis
# 128            Flaveria australasica
# 211            Flaveria australasica
# 90                  Euglena gracilis
# 223                 Euglena gracilis
# 214        Phaeodactylum tricornutum
# 273        Phaeodactylum tricornutum
# 99         Rhodobacter sphaeroides I
# 226        Rhodobacter sphaeroides I
# 115           Allochromatium vinosum
# 205           Allochromatium vinosum
# 91              Scenedesmus obliquus
# 227             Scenedesmus obliquus
# 98        Rhodobacter sphaeroides II
# 229       Rhodobacter sphaeroides II
# 100         Aphanizomenon flos aquae
# 221         Aphanizomenon flos aquae
# 101         Coccochloris peniocystis
# 222         Coccochloris peniocystis
# 1       Methanococcoides burtonii L2
# 2          Methanococcoides burtonii
# 33   Urtica atrovirens ssp. bianorii
# 252                    Pisum sativum
# 250                Nicotiana tabacum
# 255                Spinacia oleracea
# 28           Lysimachia minoricensis
# 254                Spinacia oleracea
# 29                   Mentha aquatica
# 30                Pistacia lentiscus
# 12                 Triticum aestivum
# 34                Urtica membranacea
#
#                                     identifier                   short_ref  \
# 220                           sulfuraria_savir  Savir 2010 (meta-analysis)
# 275                         sulfuraria_whitney                Whitney 2001
# 94                                max_jordan81                 Jordan 1981
# 224                                  max_savir  Savir 2010 (meta-analysis)
# 218                              monilis_savir  Savir 2010 (meta-analysis)
# 274                            monilis_whitney                Whitney 2001
# 213                              tabacum_savir  Savir 2010 (meta-analysis)
# 272                            tabacum_whitney                Whitney 2001
# 139                                alba_kubien                 Kubien 2008
# 217                                 alba_savir  Savir 2010 (meta-analysis)
# 138                            pringlei_kubien                 Kubien 2008
# 216                             pringlei_savir  Savir 2010 (meta-analysis)
# 135                            oleracea_kubien                 Kubien 2008
# 215                             oleracea_savir  Savir 2010 (meta-analysis)
# 95                            expansa_jordan81                 Jordan 1981
# 228                              expansa_savir  Savir 2010 (meta-analysis)
# 96                            perenne_jordan81                 Jordan 1981
# 225                              perenne_savir  Savir 2010 (meta-analysis)
# 126                              edulis_kubien                 Kubien 2008
# 210                               edulis_savir  Savir 2010 (meta-analysis)
# 128                        australasica_kubien                 Kubien 2008
# 211                         australasica_savir  Savir 2010 (meta-analysis)
# 90                           gracilis_jordan81                 Jordan 1981
# 223                             gracilis_savir  Savir 2010 (meta-analysis)
# 214                           triconutum_savir  Savir 2010 (meta-analysis)
# 273                         triconutum_whitney                Whitney 2001
# 99    rhodopseudomonas_sphaeroides_FI_jordan81                 Jordan 1981
# 226      rhodopseudomonas_sphaeroides_FI_savir  Savir 2010 (meta-analysis)
# 115                             vinosum_jordan                 Jordan 1985
# 205                              vinosum_savir  Savir 2010 (meta-analysis)
# 91                           obliquus_jordan81                 Jordan 1981
# 227                             obliquus_savir  Savir 2010 (meta-analysis)
# 98   rhodopseudomonas_sphaeroides_FII_jordan81                 Jordan 1981
# 229     rhodopseudomonas_sphaeroides_FII_savir  Savir 2010 (meta-analysis)
# 100                        flos_aquae_jordan81                 Jordan 1981
# 221                           flos_aquae_savir  Savir 2010 (meta-analysis)
# 101                       peniocystis_jordan81                 Jordan 1981
# 222                          peniocystis_savir  Savir 2010 (meta-analysis)
# 1                      burtonii_L2_coli_alonso                 Alonso 2009
# 2                 burtonii_tobacco_coli_alonso                 Alonso 2009
# 33                  atrovirens_bianorii_galmes                 Galmes 2005
# 252                               pea_uemura96                 Uemura 1996
# 250                           tobacco_uemura96                 Uemura 1996
# 255                       spinach_peg_uemura96                 Uemura 1996
# 28                         minoricensis_galmes                 Galmes 2005
# 254                           spinach_uemura96                 Uemura 1996
# 29                             aquatica_galmes                 Galmes 2005
# 30                            lentiscus_galmes                 Galmes 2005
# 12                             aestivum_brooks                 Brooks 1985
# 34                          membranacea_galmes                 Galmes 2005
#
#      primary     KC   vC      S      KO
# 220        0    3.3  1.2  166.0   374.0
# 275        1    3.3  1.2  166.0   374.0
# 94         1    9.0  NaN   82.0   430.0
# 224        0    9.0  NaN   82.0   430.0
# 218        0    9.3  2.6  167.0     NaN
# 274        1    9.3  2.6  167.0     NaN
# 213        0   10.7  3.4   82.0   295.0
# 272        1   10.7  3.4   82.0   295.0
# 139        1   11.2  2.9   78.7   415.0
# 217        0   11.2  2.9   78.7   415.0
# 138        1   12.0  3.1   80.8   666.0
# 216        0   12.0  3.1   80.8   666.0
# 135        1   12.1  3.2   79.8   574.0
# 215        0   12.1  3.2   79.8   574.0
# 95         1   13.0  NaN   81.0   600.0
# 228        0   13.0  NaN   81.0   600.0
# 96         1   16.0  NaN   80.0   500.0
# 225        0   16.0  NaN   80.0   500.0
# 126        1   18.2  4.1   77.5   289.0
# 210        0   18.2  4.1   77.5   289.0
# 128        1   22.0  3.8   77.2   309.0
# 211        0   22.0  3.8   77.2   309.0
# 90         1   25.0  NaN   54.0   410.0
# 223        0   25.0  NaN   54.0   410.0
# 214        0   27.9  3.4  113.0   467.0
# 273        1   27.9  3.4  113.0   467.0
# 99         1   36.0  NaN   62.0   840.0
# 226        0   36.0  NaN   62.0   840.0
# 115        1   37.0  6.7   41.0   290.0
# 205        0   37.0  6.7   41.0   290.0
# 91         1   38.0  NaN   63.0   660.0
# 227        0   38.0  NaN   63.0   660.0
# 98         1   80.0  NaN    9.0   220.0
# 229        0   80.0  NaN    9.0   220.0
# 100        1  105.0  NaN   48.0   990.0
# 221        0  105.0  NaN   48.0   990.0
# 101        1  121.0  NaN   47.0  1220.0
# 222        0  121.0  NaN   47.0  1220.0
# 1          1    NaN  1.9    1.1     NaN
# 2          1    NaN  1.9    1.1     NaN
# 33         1    NaN  NaN   90.2     NaN
# 252        1    NaN  NaN   90.2     NaN
# 250        1    NaN  NaN   93.1     NaN
# 255        1    NaN  NaN   93.1     NaN
# 28         1    NaN  NaN   93.8     NaN
# 254        1    NaN  NaN   93.8     NaN
# 29         1    NaN  NaN   97.2     NaN
# 30         1    NaN  NaN   97.2     NaN
# 12         1    NaN  NaN  102.0     NaN
# 34         1    NaN  NaN  102.0     NaN

# %%
# Load the data from Excel, remove data points that are not comparable.
# raw_kin_df is everything in the file, kin_df is the subset with all relevant kinetic data.
raw_kin_df, kin_df = rubisco_data.load_rubisco_data()

# Subset the data in various ways for future use
deduped_kin_df, savir_df, nonsavir_df = rubisco_data.filter_data(raw_kin_df)

# %%
# The helper function "filter_data" should drop the Savir data for which we
# have a matching primary reference containing all the data. 
get_kin_dups(deduped_kin_df)
# You can see that there is no Savir et al. data in the duplicate listing below.
# Out:
#                              species                    identifier  \
# 1       Methanococcoides burtonii L2       burtonii_L2_coli_alonso
# 2          Methanococcoides burtonii  burtonii_tobacco_coli_alonso
# 68   Urtica atrovirens ssp. bianorii    atrovirens_bianorii_galmes
# 347                    Pisum sativum                  pea_uemura96
# 345                Nicotiana tabacum              tobacco_uemura96
# 350                Spinacia oleracea          spinach_peg_uemura96
# 63           Lysimachia minoricensis           minoricensis_galmes
# 349                Spinacia oleracea              spinach_uemura96
# 64                   Mentha aquatica               aquatica_galmes
# 65                Pistacia lentiscus              lentiscus_galmes
# 45                 Triticum aestivum               aestivum_brooks
# 69                Urtica membranacea            membranacea_galmes
#
#        short_ref  primary  KC   vC      S  KO
# 1    Alonso 2009        1 NaN  1.9    1.1 NaN
# 2    Alonso 2009        1 NaN  1.9    1.1 NaN
# 68   Galmes 2005        1 NaN  NaN   90.2 NaN
# 347  Uemura 1996        1 NaN  NaN   90.2 NaN
# 345  Uemura 1996        1 NaN  NaN   93.1 NaN
# 350  Uemura 1996        1 NaN  NaN   93.1 NaN
# 63   Galmes 2005        1 NaN  NaN   93.8 NaN
# 349  Uemura 1996        1 NaN  NaN   93.8 NaN
# 64   Galmes 2005        1 NaN  NaN   97.2 NaN
# 65   Galmes 2005        1 NaN  NaN   97.2 NaN
# 45   Brooks 1985        1 NaN  NaN  102.0 NaN
# 69   Galmes 2005        1 NaN  NaN  102.0 NaN
